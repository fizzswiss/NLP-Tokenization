# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\rsaty\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\rsaty\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\rsaty\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\rsaty\anaconda3\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\rsaty\anaconda3\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\rsaty\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
corpus='Given an array, arr of n elements, and an element x, find whether element x is present in the array. Return the index of the first occurrence of x in the array, or -1 if it doesn’t exist.'

# %%
print(corpus)
# Out:
# Given an array, arr of n elements, and an element x, find whether element x is present in the array. Return the index of the first occurrence of x in the array, or -1 if it doesn’t exist.

# %%
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
documents
# Out:
# ['Given an array, arr of n elements, and an element x, find whether element x is present in the array.',
#  'Return the index of the first occurrence of x in the array, or -1 if it doesn’t exist.']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Given an array, arr of n elements, and an element x, find whether element x is present in the array.
# Return the index of the first occurrence of x in the array, or -1 if it doesn’t exist.

# %%
from nltk.tokenize import word_tokenize

words=word_tokenize(corpus)

# %%
words
# Out:
# ['Given',
#  'an',
#  'array',
#  ',',
#  'arr',
#  'of',
#  'n',
#  'elements',
#  ',',
#  'and',
#  'an',
#  'element',
#  'x',
#  ',',
#  'find',
#  'whether',
#  'element',
#  'x',
#  'is',
#  'present',
#  'in',
#  'the',
#  'array',
#  '.',
#  'Return',
#  'the',
#  'index',
#  'of',
#  'the',
#  'first',
#  'occurrence',
#  'of',
#  'x',
#  'in',
#  'the',
#  'array',
#  ',',
#  'or',
#  '-1',
#  'if',
#  'it',
#  'doesn',
#  '’',
#  't',
#  'exist',
#  '.']

# %%
for word in words:
    print(word)
# Out:
# Given
# an
# array
# ,
# arr
# of
# n
# elements
# ,
# and
# an
# element
# x
# ,
# find
# whether
# element
# x
# is
# present
# in
# the
# array
# .
# Return
# the
# index
# of
# the
# first
# occurrence
# of
# x
# in
# the
# array
# ,
# or
# -1
# if
# it
# doesn
# ’
# t
# exist
# .

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Given', 'an', 'array', ',', 'arr', 'of', 'n', 'elements', ',', 'and', 'an', 'element', 'x', ',', 'find', 'whether', 'element', 'x', 'is', 'present', 'in', 'the', 'array', '.']
# ['Return', 'the', 'index', 'of', 'the', 'first', 'occurrence', 'of', 'x', 'in', 'the', 'array', ',', 'or', '-1', 'if', 'it', 'doesn', '’', 't', 'exist', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

wordpunct_tokenize(corpus)
# Out:
# ['Given',
#  'an',
#  'array',
#  ',',
#  'arr',
#  'of',
#  'n',
#  'elements',
#  ',',
#  'and',
#  'an',
#  'element',
#  'x',
#  ',',
#  'find',
#  'whether',
#  'element',
#  'x',
#  'is',
#  'present',
#  'in',
#  'the',
#  'array',
#  '.',
#  'Return',
#  'the',
#  'index',
#  'of',
#  'the',
#  'first',
#  'occurrence',
#  'of',
#  'x',
#  'in',
#  'the',
#  'array',
#  ',',
#  'or',
#  '-',
#  '1',
#  'if',
#  'it',
#  'doesn',
#  '’',
#  't',
#  'exist',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Given',
#  'an',
#  'array',
#  ',',
#  'arr',
#  'of',
#  'n',
#  'elements',
#  ',',
#  'and',
#  'an',
#  'element',
#  'x',
#  ',',
#  'find',
#  'whether',
#  'element',
#  'x',
#  'is',
#  'present',
#  'in',
#  'the',
#  'array.',
#  'Return',
#  'the',
#  'index',
#  'of',
#  'the',
#  'first',
#  'occurrence',
#  'of',
#  'x',
#  'in',
#  'the',
#  'array',
#  ',',
#  'or',
#  '-1',
#  'if',
#  'it',
#  'doesn’t',
#  'exist',
#  '.']
